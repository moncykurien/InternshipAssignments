# %% [markdown]
# # Importing Libraries

# %%
#selenium libraries
import selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException, ElementNotInteractableException, ElementClickInterceptedException

import time as t
import pandas as pd
import re

from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC

import requests
import urllib.parse
import os
import shutil

# %%
def get_drive_launch(url):
    """
    This function initiates the Chrome browser's driver with the url passed as a parameter and returns the driver instance.
    Parameters:
        url - url of the website
    return:
        driver - driver instance of the chrome browser    
    """
    #creating driver instance
    driver = webdriver.Chrome('./driver/chromedriver.exe')
    driver.maximize_window()
    
    #defining implicit wait
    driver.implicitly_wait(10)
    
    #launching the url
    driver.get(url)
    
    return driver

# %% [markdown]
# ## 1.Scrape the details of most viewed videos on YouTube from Wikipedia:
# Url= https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos.
#
# You need to find following details:
#
# A) Rank
#
# B) Name
#
# C) Artist
#
# D) Upload date
#
# E) Views

# %%
def scrape_most_viewed_videos_youtube(url):
    table_MN = pd.read_html(url, match='Top 30 most-viewed YouTube videos')[0]
    table_MN.drop(['Note','Unnamed: 6'], axis = 1,inplace = True)
    table_MN.rename(columns={'No.':'Rank'},inplace=True)
    df = table_MN[:-1].copy()
    df['Video name'] = df['Video name'].apply(lambda x: x.split('[')[0])
    return df

# %%
url = "https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos"
data = scrape_most_viewed_videos_youtube(url)
data
# Out:
#    Rank                                   Video name  \
# 0    1.                           "Baby Shark Dance"
# 1    2.                                  "Despacito"
# 2    3.                               "Shape of You"
# 3    4.                       "Johny Johny Yes Papa"
# 4    5.                              "See You Again"
# 5    6.   "Masha and the Bear – Recipe for Disaster"
# 6    7.                                "Uptown Funk"
# 7    8.                              "Gangnam Style"
# 8    9.  "Learning Colors – Colorful Eggs on a Farm"
# 9   10.                                  "Bath Song"
# 10  11.                "Phonics Song with Two Words"
# 11  12.                                      "Sugar"
# 12  13.                                      "Sorry"
# 13  14.                                       "Roar"
# 14  15.                             "Dame Tu Cosita"
# 15  16.                             "Counting Stars"
# 16  17.                          "Thinking Out Loud"
# 17  18.                                 "Dark Horse"
# 18  19.                                      "Faded"
# 19  20.                               "Shake It Off"
# 20  21.                                    "Lean On"
# 21  22.                                   "Bailando"
# 22  23.                             "Girls Like You"
# 23  24.                                 "Let Her Go"
# 24  25.                                   "Mi Gente"
# 25  26.                          "Wheels on the Bus"
# 26  27.                                      "Hello"
# 27  28.                                    "Perfect"
# 28  29.           "Waka Waka (This Time for Africa)"
# 29  30.                                     "Axel F"
#
#                           Uploader Views (billions)        Upload date
# 0   Pinkfong Kids' Songs & Stories             8.44      June 17, 2016
# 1                       Luis Fonsi             7.32   January 12, 2017
# 2                       Ed Sheeran             5.29   January 30, 2017
# 3                      LooLoo Kids             5.24    October 8, 2016
# 4                      Wiz Khalifa             5.08      April 6, 2015
# 5                       Get Movies             4.43   January 31, 2012
# 6                      Mark Ronson             4.16  November 19, 2014
# 7                              Psy             4.05      July 15, 2012
# 8                      Miroshka TV             3.97  February 27, 2018
# 9       Cocomelon – Nursery Rhymes             3.95        May 2, 2018
# 10                       ChuChu TV             3.78      March 6, 2014
# 11                        Maroon 5             3.45   January 14, 2015
# 12                   Justin Bieber             3.43   October 22, 2015
# 13                      Katy Perry             3.34  September 5, 2013
# 14                       El Chombo             3.28      April 5, 2018
# 15                     OneRepublic             3.27       May 31, 2013
# 16                      Ed Sheeran             3.24    October 7, 2014
# 17                      Katy Perry             3.05  February 20, 2014
# 18                     Alan Walker             3.05   December 3, 2015
# 19                    Taylor Swift             3.05    August 18, 2014
# 20            Major Lazer Official             3.02     March 22, 2015
# 21                Enrique Iglesias             3.01     April 11, 2014
# 22                        Maroon 5             3.01       May 31, 2018
# 23                       Passenger             2.97      July 25, 2012
# 24                        J Balvin             2.90      June 29, 2017
# 25      Cocomelon – Nursery Rhymes             2.89       May 24, 2018
# 26                           Adele             2.83   October 22, 2015
# 27                      Ed Sheeran             2.82   November 9, 2017
# 28                         Shakira             2.80       June 4, 2010
# 29                      Crazy Frog             2.77      June 16, 2009

# %% [markdown]
# ## 2. Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.
#
# You need to find following details:
#
# A) Match title (I.e. 1st ODI)
#
# B) Series
#
# C) Place
#
# D) Date
#
# E) Time
#
# Note: - From bcci.tv home page you have reach to the international fixture page through code

# %%
def scrape_bcci_fixture(url, choice):
    d = get_drive_launch(url)
    url = d.find_element_by_xpath("//div[contains(text(),'"+choice+"')]/following-sibling::div//ul//a[contains(text(),'Fixtures')]").get_attribute('href')
    d.quit()
    d = get_drive_launch(url)

    match_titles = []
    series_lst = []
    places = []
    dates = []
    times = []

    titles_elemns = d.find_elements_by_xpath("//strong[@class='fixture__name fixture__name--with-margin']")
    series_elemns = d.find_elements_by_xpath("//div[@class='fixture__format-strip']")
    places_elemns = d.find_elements_by_xpath("//strong[@class='fixture__name fixture__name--with-margin']/following-sibling::span")
    dates_elemns = d.find_elements_by_xpath("//span[@class='fixture__date']")
    months_elemns = d.find_elements_by_xpath("//span[@class='fixture__month']")
    years_elemns = d.find_elements_by_xpath("//h3[@class='event-list__date js-date']")
    times_elemns = d.find_elements_by_xpath("//span[@class='fixture__time']")

    for title, series, place, date, month, time in zip(titles_elemns,series_elemns,places_elemns,dates_elemns,months_elemns, times_elemns):
        match_titles.append(title.text.strip())
        series_lst.append(series.text.strip().replace('\n',' Match - '))
        places.append(place.text.strip())
        yr = ''
        for i in years_elemns:
            if month.text.lower() in i.text.lower():
                yr = i.text.strip()
                break
        dates.append(date.text.strip()+" "+yr)
        times.append(time.text.strip())

    data = pd.DataFrame({'Match Title':match_titles, 'Series':series_lst, 'Place':places, 'Date':dates, 'Time':times})
    return d, data

# %%
url = 'https://www.bcci.tv/'
d, df = scrape_bcci_fixture(url, 'International')
d.quit()
df
# Out:
#   Match Title                                          Series  \
# 0       Final  TEST Match - ICC WORLD TEST CHAMPIONSHIP FINAL
# 1    1st Test               TEST Match - ENGLAND V INDIA 2021
# 2    2nd Test               TEST Match - ENGLAND V INDIA 2021
# 3    3rd Test               TEST Match - ENGLAND V INDIA 2021
# 4    4th Test               TEST Match - ENGLAND V INDIA 2021
# 5    5th Test               TEST Match - ENGLAND V INDIA 2021
#
#                          Place               Date       Time
# 0  The Ageas Bowl, Southampton       18 June 2021  15:30 IST
# 1     Trent Bridge, Nottingham     04 August 2021  15:30 IST
# 2               Lord's, London     12 August 2021  15:30 IST
# 3            Headingley, Leeds     25 August 2021  15:30 IST
# 4             The Oval, London  02 September 2021  15:30 IST
# 5     Old Trafford, Manchester  10 September 2021  15:30 IST

# %% [markdown]
# ## 3. Scrape the details of selenium exception from guru99.com.
#
# Url = https://www.guru99.com/
#
# You need to find following details:
#
# A) Name
#
# B) Description
#
# Note: - From guru99 home page you have to reach to selenium exception handling page through code.

# %%
def scrape_guru(url):
    d = get_drive_launch(url)
    d.find_element_by_xpath("//a[contains(text(),'Selenium')]").click()
    t.sleep(2)

    d.find_element_by_xpath("//a[@title='Selenium Exception Handling (Common Exceptions List)']").click()
    t.sleep(2)
    url = d.current_url
    df = pd.read_html(url)[0]
    df.columns = df.iloc[0]
    df.drop(0,inplace=True)
    
    return d,df

# %%
url = 'https://www.guru99.com/'
d,data = scrape_guru(url) 
d.quit()
data
# Out:
# 0                        Exception name  \
# 1            ElementNotVisibleException
# 2         ElementNotSelectableException
# 3                NoSuchElementException
# 4                  NoSuchFrameException
# 5               NoAlertPresentException
# 6                 NoSuchWindowException
# 7        StaleElementReferenceException
# 8              SessionNotFoundException
# 9                      TimeoutException
# 10                   WebDriverException
# 11            ConnectionClosedException
# 12     ElementClickInterceptedException
# 13      ElementNotInteractableException
# 14             ErrorInResponseException
# 15  ErrorHandler.UnknownServerException
# 16         ImeActivationFailedException
# 17             ImeNotAvailableException
# 18         InsecureCertificateException
# 19             InvalidArgumentException
# 20         InvalidCookieDomainException
# 21          InvalidCoordinatesException
# 22          InvalidElementStateExceptio
# 23            InvalidSessionIdException
# 24       InvalidSwitchToTargetException
# 25                  JavascriptException
# 26                        JsonException
# 27             NoSuchAttributeException
# 28       MoveTargetOutOfBoundsException
# 29               NoSuchContextException
# 30                NoSuchCookieException
# 31                    NotFoundException
# 32          RemoteDriverServerException
# 33                  ScreenshotException
# 34           SessionNotCreatedException
# 35           UnableToSetCookieException
# 36           UnexpectedTagNameException
# 37              UnhandledAlertException
# 38      UnexpectedAlertPresentException
# 39               UnknownMethodException
# 40          UnreachableBrowserException
# 41          UnsupportedCommandException
#
# 0                                         Description
# 1   This type of Selenium exception occurs when an...
# 2   This Selenium exception occurs when an element...
# 3   This Exception occurs if an element could not ...
# 4   This Exception occurs if the frame target to b...
# 5   This Exception occurs when you switch to no pr...
# 6   This Exception occurs if the window target to ...
# 7   This Selenium exception occurs happens when th...
# 8   The WebDriver is acting after you quit the bro...
# 9   Thrown when there is not enough time for a com...
# 10  This Exception takes place when the WebDriver ...
# 11  This type of Exception takes place when there ...
# 12  The command may not be completed as the elemen...
# 13  This Selenium exception is thrown when any ele...
# 14  This happens while interacting with the Firefo...
# 15  Exception is used as a placeholder in case if ...
# 16  This expectation will occur when IME engine ac...
# 17    It takes place when IME support is unavailable.
# 18  Navigation made the user agent to hit a certif...
# 19  It occurs when an argument does not belong to ...
# 20  This happens when you try to add a cookie unde...
# 21  This type of Exception matches an interacting ...
# 22  It occurs when command can't be finished when ...
# 23  This Exception took place when the given sessi...
# 24  This occurs when the frame or window target to...
# 25  This issue occurs while executing JavaScript g...
# 26  It occurs when you afford to get the session w...
# 27  This kind of Exception occurs when the attribu...
# 28  It takes place if the target provided to the A...
# 29           ContextAware does mobile device testing.
# 30  This Exception occurs when no cookie matching ...
# 31  This Exception is a subclass of WebDriverExcep...
# 32  This Selenium exception is thrown when the ser...
# 33            It is not possible to capture a screen.
# 34  It happens when a new session could not be suc...
# 35  This occurs if a driver is unable to set a coo...
# 36  Happens if a support class did not get a web e...
# 37  This expectation occurs when there is an alert...
# 38  It occurs when there is the appearance of an u...
# 39  This Exception happens when the requested comm...
# 40  This Exception occurs only when the browser is...
# 41  This occurs when remote WebDriver does n't sen...

# %% [markdown]
# ## 4. Scrape the details of State-wise GDP of India from statisticstime.com.
#
# Url = http://statisticstimes.com/
#
# You have to find following details:
#
# A) Rank
#
# B) State
#
# C) GSDP(18-19)
#
# D) GSDP(17-18)
#
# E) Share(2017)
#
# F) GDP($ billion)
#
# Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
def scrape_statewise_gdp_india(url):
    d = get_drive_launch(url)
    d.find_element_by_xpath("//button[contains(text(),'Economy')]").click()
    d.find_element_by_xpath("//button[contains(text(),'Economy')]/following-sibling::div//a[contains(text(),'India')]").click()
    t.sleep(2)
    frame0 = d.find_element_by_xpath("//iframe[@id='aswift_2']")
    d.switch_to.frame(frame0)
    frame = d.find_element_by_xpath("//iframe[@id='ad_iframe']")
    d.switch_to.frame(frame)
    d.find_element_by_xpath("//div[@id='mys-wrapper']//div[@id='dismiss-button']").click()
    t.sleep(2)
    d.switch_to.default_content()
    d.find_element_by_xpath("//a[contains(text(),'GDP of Indian states')]").click()

    t.sleep(2)
    url = d.current_url
    df = pd.read_html(url,match='GSDP')[0]
    df.drop(df.columns[-2:], axis=1, inplace = True)
    df.columns = ['Rank','State','GSDP(19-20)','GSDP(18-19)','Share(2018)','GDP($ billion)']
    df = df.iloc[:-1]
    df['Rank'] = df['Rank'].astype(int)
    d.quit()
    return df

# %%
url = 'http://statisticstimes.com/'
data = scrape_statewise_gdp_india(url)
data
# Out:
#     Rank                      State GSDP(19-20) GSDP(18-19) Share(2018)  \
# 0      1                Maharashtra           -     2632792      13.88%
# 1      2                 Tamil Nadu     1845853     1630208       8.59%
# 2      3              Uttar Pradesh     1687818     1584764       8.35%
# 3      4                    Gujarat           -     1502899       7.92%
# 4      5                  Karnataka     1631977     1493127       7.87%
# 5      6                West Bengal     1253832     1089898       5.75%
# 6      7                  Rajasthan     1020989      942586       4.97%
# 7      8             Andhra Pradesh      972782      862957       4.55%
# 8      9                  Telangana      969604      861031       4.54%
# 9     10             Madhya Pradesh      906672      809592       4.27%
# 10    11                     Kerala           -      781653       4.12%
# 11    12                      Delhi      856112      774870       4.08%
# 12    13                    Haryana      831610      734163       3.87%
# 13    14                      Bihar      611804      530363       2.80%
# 14    15                     Punjab      574760      526376       2.77%
# 15    16                     Odisha      521275      487805       2.57%
# 16    17                      Assam           -      315881       1.67%
# 17    18               Chhattisgarh      329180      304063       1.60%
# 18    19                  Jharkhand      328598      297204       1.57%
# 19    20                Uttarakhand           -      245895       1.30%
# 20    21            Jammu & Kashmir           -      155956       0.82%
# 21    22           Himachal Pradesh      165472      153845       0.81%
# 22    23                        Goa       80449       73170       0.39%
# 23    24                    Tripura       55984       49845       0.26%
# 24    25                 Chandigarh           -       42114       0.22%
# 25    26                 Puducherry       38253       34433       0.18%
# 26    27                  Meghalaya       36572       33481       0.18%
# 27    28                     Sikkim       32496       28723       0.15%
# 28    29                    Manipur       31790       27870       0.15%
# 29    30                   Nagaland           -       27283       0.14%
# 30    31          Arunachal Pradesh           -       24603       0.13%
# 31    32                    Mizoram       26503       22287       0.12%
# 32    33  Andaman & Nicobar Islands           -           -           -
#
#    GDP($ billion)
# 0         398.145
# 1         246.529
# 2         239.656
# 3         227.276
# 4         225.798
# 5         164.820
# 6         142.543
# 7         130.501
# 8         130.210
# 9         122.431
# 10        118.206
# 11        117.180
# 12        111.024
# 13         80.204
# 14         79.601
# 15         73.768
# 16         47.769
# 17         45.982
# 18         44.945
# 19         37.186
# 20         23.584
# 21         23.265
# 22         11.065
# 23          7.538
# 24          6.369
# 25          5.207
# 26          5.063
# 27          4.344
# 28          4.215
# 29          4.126
# 30          3.721
# 31          3.370
# 32              -

# %% [markdown]
# ## 5. Scrape the details of trending repositories on Github.com.
#
# Url = https://github.com/
#
# You have to find the following details:
#
# A) Repository title
#
# B) Repository description
#
# C) Contributors count
#
# D) Language used

# %%
url = 'https://github.com/'
d = get_drive_launch(url)
d.find_element_by_xpath("//summary[contains(text(),'Explore')]").click()
d.find_element_by_xpath("//a[contains(text(),'Trending ')]").click()

# %% [markdown]
# ## 6. Scrape the details of top 100 songs on billiboard.com.
#
# Url = https://www.billboard.com/
#
# You have to find the following details:
#
# A) Song name
#
# B) Artist name
#
# C) Last week rank
#
# D) Peak rank
#
# E) Weeks on board
#
# Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
url = 'https://www.billboard.com/'
d = get_drive_launch(url)

# %% [markdown]
# ## 7. Scrape the details of Data science recruiters from naukri.com.
#
# Url = https://www.naukri.com/
#
# You have to find the following details:
#
# A) Name
#
# B) Designation
#
# C) Company
#
# D) Skills they hire for
#
# E) Location
#
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and
# click on search. All this should be done through code

# %%
def get_naukri_recruiters_details(url, search_key):
    names = []
    designs = []
    comps = []
    skills = []
    locations = []
    d = get_drive_launch(url)
    main_window = d.current_window_handle
    d.find_element_by_xpath("//div[contains(text(),'Recruiters')]").click()
    windows = d.window_handles
    d.switch_to.window(windows[1])
    t.sleep(2)
    d.find_element_by_xpath("//input[@placeholder='Skills, Designations, Companies']").send_keys(search_key)
    d.find_element_by_xpath("//button[@type='submit']").click()

    name_elems = d.find_elements_by_xpath("//p[@class='highlightable']/a[1]")

    for name_ele in name_elems:

        name = name_ele.text
        try:
            names.append(d.find_element_by_xpath("//a[@title='"+name+"']/../a").text)
        except NoSuchElementException:
            try:
                names.append(d.find_element_by_xpath("//a[@title='"+name+" ']/../a").text)
            except NoSuchElementException:
                names.append("-")

        try:
            designs.append(d.find_element_by_xpath("//a[@title='"+name+"']/../span[1]").text)
        except NoSuchElementException:
            try:
                designs.append(d.find_element_by_xpath("//a[@title='"+name+" ']/../span[1]").text)
            except NoSuchElementException:
                designs.append("-")

        try:
            comps.append(d.find_element_by_xpath("//a[@title='"+name+"']/../a[2]").text)
        except NoSuchElementException:
            try:
                comps.append(d.find_element_by_xpath("//a[@title='"+name+" ']/../a[2]").text)
            except NoSuchElementException:
                comps.append("-")

        try:
            skills.append(d.find_element_by_xpath("//a[@title='"+name+"']/../../following-sibling::div[@class='hireSec highlightable'][1]").text)
        except NoSuchElementException:
            try:
                skills.append(d.find_element_by_xpath("//a[@title='"+name+" ']/../../following-sibling::div[@class='hireSec highlightable'][1]").text)
            except NoSuchElementException:
                skills.append("-")

        try:
            locations.append(d.find_element_by_xpath("//a[@title='"+name+"']/../span[2]").text)
        except NoSuchElementException:
            try:
                locations.append(d.find_element_by_xpath("//a[@title='"+name+" ']/../span[2]").text)
            except NoSuchElementException:
                locations.append("-")
    df = pd.DataFrame({'Name':names, 'Designation':designs, 'Company':comps, 'Skills they hire for':skills, 'Location':locations})
    return d,df

# %%
url = 'https://www.naukri.com/'
d, data = get_naukri_recruiters_details(url, 'Data science')
d.quit()
data
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                    Talent Acquisition Executive
# 3                                    Anik Agrawal
# 4                        MARSIAN Technologies LLP
# 5                                    subhas patel
# 6    Abhishek - Only Analytics Hiring - India and
# 7   Institute for Financial Management and Resear
# 8                                     Balu Ramesh
# 9                                   Asif Lucknowi
# 10                                InstaFinancials
# 11                                Kalpana Dumpala
# 12                                        Mubarak
# 13                                 Kushal Rastogi
# 14                                    Ruchi Dhote
# 15                             Mahesh Babu Channa
# 16                                  Manisha Yadav
# 17                                   Kapil Devang
# 18                                Dhruv Dev Dubey
# 19                                    Riya Rajesh
# 20                           Rashmi Bhattacharjee
# 21                                  Faizan Kareem
# 22                                 Rithika dadwal
# 23                                  Azahar Shaikh
# 24                             Sandhya Khandagale
# 25                                      Shaun Rao
# 26                                          Manas
# 27                                          kumar
# 28                                   Sunil Vedula
# 29                                    Rajat Kumar
# 30                                      Jayanth N
# 31                                  Prateek Kumar
# 32                                    Amit Sharma
# 33                                          Kanan
# 34                           Shashikant Chaudhary
# 35                                           Brad
# 36                                   Rutuja Pawar
# 37                            Madhusudhan Sridhar
# 38                                    Ankit Sinha
# 39                                 Gaurav Chouhan
# 40                                   Rashi Kacker
# 41                                        Ashwini
# 42                                   Balaji Kolli
# 43                                 Rajani Nagaraj
# 44                                    ROHIT Kumar
# 45                                 Amir Chowdhury
# 46                                 Shailja Mishra
# 47                                   Sunny Sharma
# 48                                     Sagar Lama
# 49                                       SREEDHAR
#
#                             Designation  \
# 0                            HR Manager
# 1                     Company Recruiter
# 2              Recruitment Professional
# 3                     Company Recruiter
# 4                            Company HR
# 5                           Founder CEO
# 6           Recruitment Lead Consultant
# 7                     Programme Manager
# 8                      HR Administrator
# 9                              Director
# 10                       Human Resource
# 11                     Executive Hiring
# 12                           Company HR
# 13                           Company HR
# 14  Senior Executive Talent Acquisition
# 15                         HR Team Lead
# 16                         HR Executive
# 17                           HR Manager
# 18             Company Recruitment Head
# 19           Manager Talent Acquisition
# 20                              HR Head
# 21                           HR MANAGER
# 22                         HR Recruiter
# 23                    Company Recruiter
# 24                         HR Recruiter
# 25              Manager Human Resources
# 26              Lead Talent acquisition
# 27                           Proprietor
# 28                                  CEO
# 29                          Founder CEO
# 30                      Project Manager
# 31                                 Head
# 32                           Consultant
# 33         senior technology instructor
# 34             HR Recruiter/HR Excutive
# 35        Manager, Technical Recruiting
# 36                  Technical Recruiter
# 37                      Erp Implementer
# 38                       Head Analytics
# 39              Chief Technical Officer
# 40                   Sr Product Manager
# 41             Director Global Delivery
# 42                           Co Founder
# 43                           HR Manager
# 44                            Architect
# 45                     Managing Partner
# 46                           HR Manager
# 47               Managing Director - HR
# 48                   Company HR Manager
# 49               Recruitment Consultant
#
#                                            Company  \
# 0                             Data Science Network
# 1                    Shore Infotech India Pvt. Ltd
# 2                                       XenonStack
# 3            Enerlytics Software Solutions Pvt Ltd
# 4                         MARSIAN Technologies LLP
# 5                                  LibraryXProject
# 6       Apidel Technologies Division of Transpower
# 7                                             IFMR
# 8                      Techvantage Systems Pvt Ltd
# 9                       Weupskill- Live Wire India
# 10                CBL Data Science Private Limited
# 11                              Innominds Software
# 12                                        MoneyTap
# 13              QuantMagnum Technologies Pvt. Ltd.
# 14                           Bristlecone India Ltd
# 15                               SocialPrachar.com
# 16                                        Easi Tax
# 17                                  BISP Solutions
# 18                                    Confidential
# 19                     Novelworx Digital Solutions
# 20         AXESTRACK SOFTWARE SOLUTIONS PRIVATE...
# 21                   FirstTech Consaltants Pvt.Ltd
# 22                                Affine Analytics
# 23                 NEAL ANALYTICS SERVICES PVT LTD
# 24                 Compumatrice Multimedia Pvt Ltd
# 25                              Exela Technologies
# 26      Autumn Leaf Consulting Services Private...
# 27                                         trainin
# 28                            Nanoprecise Sci Corp
# 29                  R.S Consultancy &amp; Services
# 30        Dollarbird Information Services Pvt, Ltd
# 31                                         Trisect
# 32                                 ASCO consulting
# 33                                         NY INST
# 34  3D India Staffing Research &amp; Consulting...
# 35                                     O.C. Tanner
# 36                                   Demand Matrix
# 37                             MADHUSUDHAN SRIDHAR
# 38                                  Suntech Global
# 39                        Strategic Consulting Lab
# 40                            Impel Labs Pvt. Ltd.
# 41                                    MRP Advisers
# 42                   Saras Solutions India Pvt Ltd
# 43                                     WildJasmine
# 44                             LNT Private Limited
# 45                                     Granular.ai
# 46                               Certybox Pvt.Ltd.
# 47                       Western Service Providers
# 48                                          AdView
# 49     JOBSMILL BUSINESS SOLUTIONS PRIVATE LIMITED
#
#                                  Skills they hire for  \
# 0   Classic ASP Developer, Internet Marketing Prof...
# 1   .Net, Java, Data Science, Linux Administration...
# 2   Web Designing, html5, Angular.js, seo, hadoop,...
# 3   Mean Stack, javascript, angularjs, mongodb, We...
# 4   Data Science, Artificial Intelligence, Machine...
# 5   Hadoop, Spark, Digital Strategy, Data Architec...
# 6   Analytics, Business Intelligence, Business Ana...
# 7                                        Data Science
# 8   Machine Learning, algorithms, Go Getter, Compu...
# 9   Technical Training, Software Development, Pres...
# 10  Software Development, It Sales, Account Manage...
# 11  Qa, Ui/ux, Java Developer, Java Architect, C++...
# 12  Business Intelligence, Data Warehousing, Data ...
# 13  Office Administration, Hr Administration, tele...
# 14  Qlikview, Qlik Sense, Microsoft Azure, Power B...
# 15  Social Media, digital media maketing, seo, smm...
# 16  Telecalling, Client Interaction, Marketing, Re...
# 17     Big Data, Hadoop, Data Analytics, Data Science
# 18  Server Administartion, Verilog, Vhdl, Digital ...
# 19                                       Data Science
# 20  Corporate Sales, Software Development, Softwar...
# 21  Data Analytics, Data Science, Machine Learning...
# 22  Data Science, Machine Learning, Python, R, Dee...
# 23  Data Science, Artificial Intelligence, Machine...
# 24  Big Data, Data Science, Artificial Intelligenc...
# 25  Java, Net, Angularjs, Hr, Infrastructure, Mana...
# 26  Software Architecture, Vp Engineering, Product...
# 27  Data Science, Hadoop, Rpas, Devops, Python, Aw...
# 28  Signal Processing, Machine Learning, Neural Ne...
# 29  Web Technologies, Project Management, Software...
# 30  Data Analytics, Managed Services, Team Leading...
# 31  Java, Python, Angularjs, Software Testing, Mac...
# 32  Machine Learning, Artificial Intelligence, Dat...
# 33  C, C++, Artificial Intelligence, Python, Php, ...
# 34  Relationship Management, Retail Sales, Private...
# 35                 Data Science, Software Engineering
# 36  Data Science, Big Data Analytics, Digital Mark...
# 37                  Data Science, Recruitment, Salary
# 38  B.Tech, Tableau, Statistics, R, Analytics, Tim...
# 39  Software Development, Business Intelligence, B...
# 40                   Data Science, Node.js, Angularjs
# 41  Data Science, Media Marketing, Resource Planni...
# 42  Data Analysis, Learning, Data Science, Compute...
# 43  Java, Hadoop, R, Machine Learning, Spark, Flum...
# 44  Software Development, Core Java, Unit Testing,...
# 45  Machine Learning, Data Science, Product Manage...
# 46  consulting, Education Counseling, Educational ...
# 47  Software Professionals, Engineering, Technical...
# 48  Full Stack Developers, Product Manager, Data S...
# 49  Data Science, Machine Learning, Big Data Analy...
#
#                     Location
# 0                      Delhi
# 1   Hyderabad / Secunderabad
# 2                 Chandigarh
# 3                  Ahmedabad
# 4                       Pune
# 5              UK - (london)
# 6          Vadodara / Baroda
# 7                    Chennai
# 8                 Trivandrum
# 9                     Indore
# 10     Bengaluru / Bangalore
# 11  Hyderabad / Secunderabad
# 12     Bengaluru / Bangalore
# 13                    Mumbai
# 14                    Nagpur
# 15  Hyderabad / Secunderabad
# 16               Navi Mumbai
# 17                    Bhopal
# 18     Bengaluru / Bangalore
# 19                    Cochin
# 20                     Delhi
# 21  Hyderabad / Secunderabad
# 22                      Pune
# 23                      Pune
# 24                      Pune
# 25                      Pune
# 26     Bengaluru / Bangalore
# 27     Bengaluru / Bangalore
# 28                         -
# 29                     Delhi
# 30           Mysoru / Mysore
# 31                     Noida
# 32                 New Delhi
# 33                   Chennai
# 34                   Aligarh
# 35            Salt Lake City
# 36                      Pune
# 37     Bengaluru / Bangalore
# 38                    Mumbai
# 39                    Indore
# 40     Bengaluru / Bangalore
# 41                    MYSORE
# 42  Hyderabad / Secunderabad
# 43     Bengaluru / Bangalore
# 44                    Mumbai
# 45                         -
# 46                     Noida
# 47                    Mumbai
# 48     Bengaluru / Bangalore
# 49  Hyderabad / Secunderabad

# %% [markdown]
# ## 8. Scrape the details of Highest selling novels.
#
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare/
#
# You have to find the following details:
#
# A) Book name
#
# B) Author name
#
# C) Volumes sold
#
# D) Publisher
#
# E) Genre

# %%
def get_highest_selling_novels(url):
    web_table_name = 'Top 100 best selling books of all time'
    data = pd.read_html(url,match = web_table_name)[0]
    return data

# %%
url = 'https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare/'
df = get_highest_selling_novels(url)
df
# Out:
#                           Rank  \
# 0                            1
# 1                            2
# 2                            3
# 3                            4
# 4                            5
# ..                         ...
# 96                          97
# 97                          98
# 98                          99
# 99                         100
# 100  SOURCE: NIELSEN BOOK SCAN
#
#                                                  Title  \
# 0                                    Da Vinci Code,The
# 1                 Harry Potter and the Deathly Hallows
# 2             Harry Potter and the Philosopher's Stone
# 3            Harry Potter and the Order of the Phoenix
# 4                                 Fifty Shades of Grey
# ..                                                 ...
# 96                      Happy Days with the Naked Chef
# 97               Hunger Games,The:Hunger Games Trilogy
# 98   Lost Boy,The:A Foster Child's Search for the L...
# 99   Jamie's Ministry of Food:Anyone Can Learn to C...
# 100                          SOURCE: NIELSEN BOOK SCAN
#
#                         Author               Volume Sales  \
# 0                   Brown, Dan                    5094805
# 1                Rowling, J.K.                    4475152
# 2                Rowling, J.K.                    4200654
# 3                Rowling, J.K.                    4179479
# 4                 James, E. L.                    3758936
# ..                         ...                        ...
# 96               Oliver, Jamie                     794201
# 97            Collins, Suzanne                     792187
# 98                Pelzer, Dave                     791507
# 99               Oliver, Jamie                     791095
# 100  SOURCE: NIELSEN BOOK SCAN  SOURCE: NIELSEN BOOK SCAN
#
#                      Publisher                        Genre
# 0                   Transworld  Crime, Thriller & Adventure
# 1                   Bloomsbury           Children's Fiction
# 2                   Bloomsbury           Children's Fiction
# 3                   Bloomsbury           Children's Fiction
# 4                 Random House              Romance & Sagas
# ..                         ...                          ...
# 96                     Penguin        Food & Drink: General
# 97             Scholastic Ltd.          Young Adult Fiction
# 98                       Orion           Biography: General
# 99                     Penguin        Food & Drink: General
# 100  SOURCE: NIELSEN BOOK SCAN    SOURCE: NIELSEN BOOK SCAN
#
# [101 rows x 6 columns]

# %% [markdown]
# ## 9. Scrape the details most watched tv series of all time from imdb.com.
#
# Url = https://www.imdb.com/list/ls095964455/
#
# You have to find the following details:
#
# A) Name
#
# B) Year span
#
# C) Genre
#
# D) Run time
#
# E) Rating
#
# F) Votes

# %%
url = 'https://www.imdb.com/list/ls095964455/'
d = get_drive_launch(url)

# %% [markdown]
# ## 10. Details of Datasets from UCI machine learning repositories.
#
# Url = https://archive.ics.uci.edu/
#
# You have to find the following details:
#
# A) Dataset name
#
# B) Data type
#
# C) Task
#
# D) Attribute type
#
# E) No of instances
#
# F) No of attribute
#
# G) Year
#
# Note: - from the home page you have to go to the Show All Dataset page through code.

# %%
def get_uci_datasets_details(url):
    d = get_drive_launch(url)
    d.find_element_by_xpath("//b[contains(text(),'View ALL Data Sets')]").click()
    t.sleep(2)
    url = d.current_url
    d.quit()
    data = pd.read_html(url)[5]
    data.drop(0, inplace = True)
    data.columns = ['Dataset name','Data type','Task','Attribute type','No of instances','No of attribute','Year']
    return data

# %%
url = 'https://archive.ics.uci.edu/'
df = get_uci_datasets_details(url)
df
# Out:
#                                  Dataset name                  Data type  \
# 1                                     Abalone               Multivariate
# 2                                       Adult               Multivariate
# 3                                   Annealing               Multivariate
# 4                Anonymous Microsoft Web Data                        NaN
# 5                                  Arrhythmia               Multivariate
# ..                                        ...                        ...
# 581                Wisesight Sentiment Corpus         Multivariate, Text
# 582  AI4I 2020 Predictive Maintenance Dataset  Multivariate, Time-Series
# 583                          Dry Bean Dataset               Multivariate
# 584          in-vehicle coupon recommendation               Multivariate
# 585                       Gait Classification               Multivariate
#
#                                              Task              Attribute type  \
# 1                                  Classification  Categorical, Integer, Real
# 2                                  Classification        Categorical, Integer
# 3                                  Classification  Categorical, Integer, Real
# 4                             Recommender-Systems                 Categorical
# 5                                  Classification  Categorical, Integer, Real
# ..                                            ...                         ...
# 581                                Classification                         NaN
# 582  Classification, Regression, Causal-Discovery                        Real
# 583                                Classification               Integer, Real
# 584                                Classification                         NaN
# 585                                Classification                        Real
#
#     No of instances No of attribute  Year
# 1              4177               8  1995
# 2             48842              14  1996
# 3               798              38   NaN
# 4             37711             294  1998
# 5               452             279  1998
# ..              ...             ...   ...
# 581           26737               4  2020
# 582           10000              14  2020
# 583           13611              17  2020
# 584           12684              23  2020
# 585              48             321  2020
#
# [585 rows x 7 columns]
